# %%
#import sys
from helpers.runners import run_lisbon,run_tuebingen,benchmark_function
from helpers.drawers import plot_execution_times
from methods.LINGAM import lingam
from methods.IGCI import igci
from methods.LOCI import loci
from methods.LCUBE import lcube

# %%
test_file="datasets/Lisbon/data/economy/taxi_fare_prediction/distance_traveled_fare.txt"
#RUN FUNCTIONS ONE AT A TIME; TO BREAK WHEN TOO LONG
benchmark_function(loci, test_file)
# Out:
# ⏱ Running loci with 10 points...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 test_file="datasets/Lisbon/data/economy/taxi_fare_prediction/distance_traveled_fare.txt"
#       2 #RUN FUNCTIONS ONE AT A TIME; TO BREAK WHEN TOO LONG
# ----> 3 benchmark_function(loci, test_file)
#
# File c:\Users\Tiago\Desktop\Causal-Discovery-In-Exchangeable-Data\helpers\runners.py:141, in benchmark_function(func, test_file, write_dir, overwrite, seed, *args, **kwargs)
#     139 start = time.time()
#     140 try:
# --> 141     func(subset, *args, **kwargs)
#     142 except Exception as e:
#     143     print(f"⚠️ Error at n={n_points}: {e}")
#
# File c:\Users\Tiago\Desktop\Causal-Discovery-In-Exchangeable-Data\methods\LOCI.py:14, in loci(d)
#      12 x = x.flatten()
#      13 y = y.flatten()
# ---> 14 return loci_original(x,y)
#
# ...

# %%
plot_execution_times(data_dir="results")
# Out:
# 📊 Crossing Points:
# IGCI: reaches 30s at ≈ 60266241.14 points
# LiNGAM: reaches 30s at ≈ 383117159.86 points
# {'igci': 60266241.140414864, 'lingam': 383117159.8605189}
