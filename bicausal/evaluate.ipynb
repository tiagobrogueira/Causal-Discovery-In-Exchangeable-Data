# %%
from bicausal.metrics.evaluators import evaluate_tuebingen,evaluate_lisbon

# %%
evaluate_tuebingen(methods=["IGCI"])
# Out:
# ✅ Evaluation complete. Results written to results/results.csv
#   method                      parameters   dataset   Alameda     AUROC  \
# 0   IGCI                                  Tübingen  0.728734  0.724099
# 1   IGCI  {"kwargs":{"norm":"gaussian"}}  Tübingen  0.694081  0.694858
#
#              timestamp
# 0  2025-11-14 14:22:42
# 1  2025-11-14 14:22:42

# %%
evaluate_lisbon()
# Out:
# ✅ Evaluation complete. Results written to results/results.csv
# ✅ Evaluation complete. Results written to results/results.csv
# ✅ Evaluation complete. Results written to results/results.csv
# ✅ Evaluation complete. Results written to results/results.csv
# ✅ Evaluation complete. Results written to results/results.csv
# ✅ Evaluation complete. Results written to results/results.csv
#   method                      parameters   dataset   Alameda     AUROC  \
# 0   IGCI                                  Tübingen  0.728734  0.724099
# 1   IGCI  {"kwargs":{"norm":"gaussian"}}  Tübingen  0.694081  0.694858
# 2   IGCI                                    Lisbon  0.657086  0.660324
#
#              timestamp
# 0  2025-11-14 14:22:42
# 1  2025-11-14 14:22:42
# 2  2025-11-14 14:53:54
