# %%
from bicausal.metrics.evaluators import evaluate_tuebingen

# %%
evaluate_tuebingen()
# Out:
# ✅ Evaluation complete. Results written to results/results.csv
#    method                      parameters   dataset   Alameda     AUROC
# 0    IGCI                                  Tübingen  0.728734  0.499438
# 1    IGCI  {"kwargs":{"norm":"gaussian"}}  Tübingen  0.694081  0.467796
# 2  LiNGAM                                  Tübingen  0.510633  0.516486
