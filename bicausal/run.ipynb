# %%
#import sys
from bicausal.helpers.runners import run_lisbon,run_tuebingen, run_ce, run_anlsmn, run_sim

from bicausal.methods.ANM import anm
from bicausal.methods.CDCI import cdci
from bicausal.methods.CDS import cds
from bicausal.methods.CGNN import cgnn
from bicausal.methods.FOM import fom
from bicausal.methods.HECI import heci
from bicausal.methods.IGCI import igci
from bicausal.methods.LCUBE import lcube
from bicausal.methods.LOCI import loci
from bicausal.methods.NNCL import nncl
from bicausal.methods.RECI import reci
from bicausal.methods.ROCHE import roche

from bicausal.methods.RDMDL import rdmdl
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
run_tuebingen(loci)
# Out:
# ⏩ Skipping Pair 1 for LOCI (already computed with same parameters)
# ⏩ Skipping Pair 2 for LOCI (already computed with same parameters)
# ⏩ Skipping Pair 3 for LOCI (already computed with same parameters)
# ⏩ Skipping Pair 4 for LOCI (already computed with same parameters)
# ⏩ Skipping Pair 5 for LOCI (already computed with same parameters)
# ⏩ Skipping Pair 6 for LOCI (already computed with same parameters)
# ⏩ Skipping Pair 7 for LOCI (already computed with same parameters)
# ⏩ Skipping Pair 8 for LOCI (already computed with same parameters)
# ⏩ Skipping Pair 9 for LOCI (already computed with same parameters)
# ⏩ Skipping Pair 10 for LOCI (already computed with same parameters)
# ⏩ Skipping Pair 11 for LOCI (already computed with same parameters)
# ⏩ Skipping Pair 12 for LOCI (already computed with same parameters)
# ⏩ Skipping Pair 13 for LOCI (already computed with same parameters)
# ⏩ Skipping Pair 14 for LOCI (already computed with same parameters)
# ...

# %%
run_tuebingen(cgnn,train_epochs=10,nruns=3,test_epochs=2)
# Out:
# 💾 Saved Pair 1 to CSV.
# 💾 Saved Pair 2 to CSV.
# 💾 Saved Pair 3 to CSV.
# 💾 Saved Pair 4 to CSV.
# 💾 Saved Pair 5 to CSV.
# 💾 Saved Pair 6 to CSV.
# 💾 Saved Pair 7 to CSV.
# 💾 Saved Pair 8 to CSV.
# 💾 Saved Pair 9 to CSV.
# 💾 Saved Pair 10 to CSV.
# 💾 Saved Pair 11 to CSV.
# 💾 Saved Pair 12 to CSV.
# 💾 Saved Pair 13 to CSV.
# 💾 Saved Pair 14 to CSV.
# 💾 Saved Pair 15 to CSV.
# 💾 Saved Pair 16 to CSV.
# 💾 Saved Pair 17 to CSV.
# 💾 Saved Pair 18 to CSV.
# 💾 Saved Pair 19 to CSV.
# 💾 Saved Pair 20 to CSV.
# 💾 Saved Pair 21 to CSV.
# 💾 Saved Pair 22 to CSV.
# 💾 Saved Pair 23 to CSV.
# 💾 Saved Pair 24 to CSV.
# 💾 Saved Pair 25 to CSV.
# 💾 Saved Pair 26 to CSV.
# 💾 Saved Pair 27 to CSV.
# 💾 Saved Pair 28 to CSV.
# 💾 Saved Pair 29 to CSV.
# 💾 Saved Pair 30 to CSV.
# 💾 Saved Pair 31 to CSV.
# 💾 Saved Pair 32 to CSV.
# 💾 Saved Pair 33 to CSV.
# 💾 Saved Pair 34 to CSV.
# 💾 Saved Pair 35 to CSV.
# 💾 Saved Pair 36 to CSV.
# 💾 Saved Pair 37 to CSV.
# 💾 Saved Pair 38 to CSV.
# ...

# %%
run_lisbon(cgnn,train_epochs=10,nruns=3,test_epochs=2)
# Out:
# 🔍 Processing source: canada_greenhouse_gases_2005_2006 (1 files)
# ⏩ Skipping Energy_use__GJ__Emissions__kt_.txt for CGNN (already computed with same parameters)
# 🔍 Processing source: city_weather_germany (5 files)
# ⏩ Skipping altitude_precipitation__yearly_value_averaged_over_1961-1990_.txt for CGNN (already computed with same parameters)
# ⏩ Skipping altitude_temperature__average_over_1961-1990_.txt for CGNN (already computed with same parameters)
# ⏩ Skipping latitude_temperature__averaged_over_1961-1990_.txt for CGNN (already computed with same parameters)
# ⏩ Skipping longitude_precipitation__yearly_value_averaged_over_1961-1990_.txt for CGNN (already computed with same parameters)
# ⏩ Skipping longitude_temperature__averaged_over_1961-1990_.txt for CGNN (already computed with same parameters)
# 🔍 Processing source: corn_farming (1 files)
# ⏩ Skipping Acreage_Yield.txt for CGNN (already computed with same parameters)
# 🔍 Processing source: lettuce_growth (1 files)
# ...

# %%
run_lisbon(loci)
# Out:
# 🔍 Processing source: canada_greenhouse_gases_2005_2006 (1 files)
# 💾 Saved 1 results from canada_greenhouse_gases_2005_2006.
# 🔍 Processing source: city_weather_germany (5 files)
# 💾 Saved 5 results from city_weather_germany.
# 🔍 Processing source: corn_farming (1 files)
# 💾 Saved 1 results from corn_farming.
# 🔍 Processing source: lettuce_growth (1 files)
# 💾 Saved 1 results from lettuce_growth.
# 🔍 Processing source: soil_moisture_hyperspectral (250 files)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 run_lisbon(loci)
#
# File ~\Desktop\Causal-Discovery-In-Exchangeable-Data\bicausal\helpers\runners.py:116, in run_lisbon(func, read_dir, write_dir, overwrite, *args, **kwargs)
#     114     df = pd.read_csv(path, sep=None, engine="python", header=None)
#     115     x, y = df.iloc[:, 0].to_numpy(), df.iloc[:, 1].to_numpy()
# ...

# %%
#run_tuebingen(anm)
#run_tuebingen(cdci)
run_tuebingen(cds)
#run_tuebingen(cgnn)
#run_tuebingen(fom)
#run_tuebingen(heci)
#run_tuebingen(igci)
#run_tuebingen(lcube)

#run_tuebingen(nncl)
#run_tuebingen(reci)

#run_tuebingen(loci)
#run_tuebingen(roche)
# Out:
# 1 1
# 💾 Saved Pair 1 to CSV.
# 1 1
# 💾 Saved Pair 2 to CSV.
# 1 1
# 💾 Saved Pair 3 to CSV.
# 1 1
# 💾 Saved Pair 4 to CSV.
# 1 1
# 💾 Saved Pair 5 to CSV.
# 1 1
# 💾 Saved Pair 6 to CSV.
# 1 1
# 💾 Saved Pair 7 to CSV.
# 1 1
# 💾 Saved Pair 8 to CSV.
# 1 1
# 💾 Saved Pair 9 to CSV.
# 1 1
# 💾 Saved Pair 10 to CSV.
# 1 1
# 💾 Saved Pair 11 to CSV.
# 1 1
# 💾 Saved Pair 12 to CSV.
# 1 1
# 💾 Saved Pair 13 to CSV.
# 1 1
# 💾 Saved Pair 14 to CSV.
# 1 1
# 💾 Saved Pair 15 to CSV.
# 1 1
# 💾 Saved Pair 16 to CSV.
# 1 1
# 💾 Saved Pair 17 to CSV.
# 1 1
# 💾 Saved Pair 18 to CSV.
# 1 1
# 💾 Saved Pair 19 to CSV.
# 1 1
# 💾 Saved Pair 20 to CSV.
# 1 1
# 💾 Saved Pair 21 to CSV.
# 1 1
# 💾 Saved Pair 22 to CSV.
# 1 1
# 💾 Saved Pair 23 to CSV.
# 1 1
# 💾 Saved Pair 24 to CSV.
# 1 1
# 💾 Saved Pair 25 to CSV.
# 1 1
# 💾 Saved Pair 26 to CSV.
# 1 1
# 💾 Saved Pair 27 to CSV.
# 1 1
# 💾 Saved Pair 28 to CSV.
# 1 1
# 💾 Saved Pair 29 to CSV.
# 1 1
# 💾 Saved Pair 30 to CSV.
# 1 1
# 💾 Saved Pair 31 to CSV.
# 1 1
# ...

# %%
run_lisbon(anm)
run_lisbon(cdci)
run_lisbon(cds)
#run_lisbon(cgnn)
run_lisbon(fom)
run_lisbon(heci)
run_lisbon(igci)
run_lisbon(lcube)
run_lisbon(nncl)
run_lisbon(rcc)
run_lisbon(reci)

run_lisbon(loci)
run_lisbon(roche)
# Out:
# 🔍 Processing source: canada_greenhouse_gases_2005_2006 (1 files)
# 💾 Saved 1 results from canada_greenhouse_gases_2005_2006.
# 🔍 Processing source: city_weather_germany (5 files)
# 💾 Saved 5 results from city_weather_germany.
# 🔍 Processing source: corn_farming (1 files)
# 💾 Saved 1 results from corn_farming.
# 🔍 Processing source: lettuce_growth (1 files)
# 💾 Saved 1 results from lettuce_growth.
# 🔍 Processing source: soil_moisture_hyperspectral (250 files)
# 💾 Saved 250 results from soil_moisture_hyperspectral.
# 🔍 Processing source: tornadoes_north_america (2 files)
# 💾 Saved 2 results from tornadoes_north_america.
# 🔍 Processing source: us_drought_meteorological (69 files)
# 💾 Saved 69 results from us_drought_meteorological.
# 🔍 Processing source: us_wildfires_lightning_2004_2015 (1 files)
# 💾 Saved 1 results from us_wildfires_lightning_2004_2015.
# 🔍 Processing source: yields2000 (8 files)
# 💾 Saved 8 results from yields2000.
# 🔍 Processing source: abalone (20 files)
# ...

# %%
run_anlsmn(lingam)
run_anlsmn(igci)
# Out:
# 🚀 Running ANLSMN dataset: AN
# ✔ Saved AN Pair 1
# ✔ Saved AN Pair 2
# ✔ Saved AN Pair 3
# ✔ Saved AN Pair 4
# ✔ Saved AN Pair 5
# ✔ Saved AN Pair 6
# C:\Users\tiago\Desktop\Causal-Discovery-In-Exchangeable-Data\bicausal\helpers\runners.py:378: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_existing = pd.concat([df_existing, pd.DataFrame([new_row])],
# ✔ Saved AN Pair 7
# ✔ Saved AN Pair 8
# ✔ Saved AN Pair 9
# ✔ Saved AN Pair 10
# ✔ Saved AN Pair 11
# ✔ Saved AN Pair 12
# ✔ Saved AN Pair 13
# ✔ Saved AN Pair 14
# ✔ Saved AN Pair 15
# ✔ Saved AN Pair 16
# ✔ Saved AN Pair 17
# ✔ Saved AN Pair 18
# ✔ Saved AN Pair 19
# ✔ Saved AN Pair 20
# ✔ Saved AN Pair 21
# ✔ Saved AN Pair 22
# ✔ Saved AN Pair 23
# ✔ Saved AN Pair 24
# ...

# %%
run_ce(lingam)
run_ce(igci)
# Out:
# 🚀 Running CE dataset: CE-Cha
# ⏩ Skipping CE-Cha Pair 1 (already computed)
# ⏩ Skipping CE-Cha Pair 2 (already computed)
# ⏩ Skipping CE-Cha Pair 3 (already computed)
# ⏩ Skipping CE-Cha Pair 4 (already computed)
# ⏩ Skipping CE-Cha Pair 5 (already computed)
# ⏩ Skipping CE-Cha Pair 6 (already computed)
# ⏩ Skipping CE-Cha Pair 7 (already computed)
# ⏩ Skipping CE-Cha Pair 8 (already computed)
# ⏩ Skipping CE-Cha Pair 9 (already computed)
# ⏩ Skipping CE-Cha Pair 10 (already computed)
# ⏩ Skipping CE-Cha Pair 11 (already computed)
# ⏩ Skipping CE-Cha Pair 12 (already computed)
# ⏩ Skipping CE-Cha Pair 13 (already computed)
# ⏩ Skipping CE-Cha Pair 14 (already computed)
# ⏩ Skipping CE-Cha Pair 15 (already computed)
# ⏩ Skipping CE-Cha Pair 16 (already computed)
# ⏩ Skipping CE-Cha Pair 17 (already computed)
# ⏩ Skipping CE-Cha Pair 18 (already computed)
# ⏩ Skipping CE-Cha Pair 19 (already computed)
# ⏩ Skipping CE-Cha Pair 20 (already computed)
# ...

# %%
run_tuebingen(lingam)
run_tuebingen(igci)
run_tuebingen(igci, norm="gaussian")
# Out:
# C:\Users\Tiago\Desktop\Causal-Discovery-In-Exchangeable-Data\bicausal\helpers\runners.py:77: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_final = pd.concat([df_existing, df_new], ignore_index=True)
# ✅ Saved Tuebingen results to results\tuebingen_scores.csv
# ✅ Saved Tuebingen results to results\tuebingen_scores.csv
# ✅ Saved Tuebingen results to results\tuebingen_scores.csv
# 'results\\tuebingen_scores.csv'

# %%
run_tuebingen(igci, mode="entropy")
# Out:
# ✅ Saved Tuebingen results to results\tuebingen_scores.csv
# 'results\\tuebingen_scores.csv'

# %%
run_lisbon(igci)
# Out:
# 🔍 Processing source: canada_greenhouse_gases_2005_2006 (1 files)
# 💾 Saved 1 results from canada_greenhouse_gases_2005_2006.
# 🔍 Processing source: city_weather_germany (5 files)
# 💾 Saved 5 results from city_weather_germany.
# 🔍 Processing source: corn_farming (1 files)
# 💾 Saved 1 results from corn_farming.
# 🔍 Processing source: lettuce_growth (1 files)
# C:\Users\tiago\Desktop\Causal-Discovery-In-Exchangeable-Data\bicausal\helpers\runners.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_results = pd.concat([df_results, df_new], ignore_index=True)
# 💾 Saved 1 results from lettuce_growth.
# 🔍 Processing source: soil_moisture_hyperspectral (250 files)
# 💾 Saved 250 results from soil_moisture_hyperspectral.
# ...
