# %%
from bicausal.helpers.timers import benchmark_function, plot_execution_times

from bicausal.methods.ANM import anm
from bicausal.methods.CDCI import cdci
from bicausal.methods.CDS import cds
from bicausal.methods.CGNN import cgnn
from bicausal.methods.FOM import fom
from bicausal.methods.HECI import heci
from bicausal.methods.IGCI import igci
from bicausal.methods.LCUBE import lcube
from bicausal.methods.LOCI import loci
from bicausal.methods.NNCL import nncl
from bicausal.methods.RCC import rcc
from bicausal.methods.RECI import reci
from bicausal.methods.ROCHE import roche
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
test_file="benchmarks/Lisbon/data/economy/taxi_fare_prediction/distance_traveled_fare.txt"
#RUN FUNCTIONS ONE AT A TIME; TO BREAK WHEN TOO LONG~
#hello
#benchmark_function(anm,test_file)
#benchmark_function(cdci,test_file)
#benchmark_function(cds,test_file)
#benchmark_function(cgnn,test_file,overwrite=True)
benchmark_function(fom,test_file)
benchmark_function(heci,test_file)
benchmark_function(igci,test_file)
benchmark_function(lcube,test_file)
benchmark_function(loci,test_file)
benchmark_function(nncl,test_file)
benchmark_function(rcc,test_file)
benchmark_function(reci,test_file)
#benchmark_function(roche,test_file)
# Out:
# ⏩ Skipping n=10 for FOM (already computed with same parameters)
# ⏩ Skipping n=27 for FOM (already computed with same parameters)
# ⏩ Skipping n=55 for FOM (already computed with same parameters)
# ⏩ Skipping n=103 for FOM (already computed with same parameters)
# ⏩ Skipping n=185 for FOM (already computed with same parameters)
# ⏩ Skipping n=324 for FOM (already computed with same parameters)
# ⏩ Skipping n=560 for FOM (already computed with same parameters)
# ⏱ Running FOM with 962 points...
# N: 797
#   File "c:\Users\tiago\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "c:\Users\tiago\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tiago\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\tiago\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ✅ Completed 962 points in 6.2815s.
# ⏱ Running FOM with 1645 points...
# N: 797
# ✅ Completed 1645 points in 4.3988s.
# ⏱ Running FOM with 2806 points...
# N: 797
# ✅ Completed 2806 points in 6.1320s.
# ⏱ Running FOM with 4780 points...
# N: 797
# ✅ Completed 4780 points in 6.1802s.
# ⏱ Running FOM with 8136 points...
# N: 797
# ✅ Completed 8136 points in 4.7617s.
# ⏱ Running FOM with 13841 points...
# N: 797
# ✅ Completed 13841 points in 4.7491s.
# ⏱ Running FOM with 23539 points...
# N: 797
# ✅ Completed 23539 points in 4.7822s.
# ⏱ Running FOM with 40026 points...
# N: 797
# ✅ Completed 40026 points in 6.3817s.
# ⏱ Running FOM with 68054 points...
# N: 797
# ✅ Completed 68054 points in 4.5374s.
# ⏱ Running FOM with 115701 points...
# N: 797
# ✅ Completed 115701 points in 4.7234s.
# ⏱ Running FOM with 196701 points...
# N: 797
# ✅ Completed 196701 points in 4.4486s.
# ⏱ Running FOM with 209673 points...
# N: 797
# ✅ Completed 209673 points in 4.9491s.
# 📊 Benchmark results saved to results\times.csv
# ⏱ Running HECI with 10 points...
# ✅ Completed 10 points in 0.0000s.
# ⏱ Running HECI with 27 points...
# ✅ Completed 27 points in 0.0000s.
# ⏱ Running HECI with 55 points...
# ✅ Completed 55 points in 0.0000s.
# ⏱ Running HECI with 103 points...
# ✅ Completed 103 points in 0.0000s.
# ⏱ Running HECI with 185 points...
# ✅ Completed 185 points in 0.0029s.
# ⏱ Running HECI with 324 points...
# ✅ Completed 324 points in 0.0132s.
# ⏱ Running HECI with 560 points...
# ✅ Completed 560 points in 0.0000s.
# ⏱ Running HECI with 962 points...
# ✅ Completed 962 points in 0.0155s.
# ⏱ Running HECI with 1645 points...
# ✅ Completed 1645 points in 0.0166s.
# ⏱ Running HECI with 2806 points...
# ✅ Completed 2806 points in 0.0208s.
# ⏱ Running HECI with 4780 points...
# ✅ Completed 4780 points in 0.0123s.
# ⏱ Running HECI with 8136 points...
# ✅ Completed 8136 points in 0.0357s.
# ⏱ Running HECI with 13841 points...
# ✅ Completed 13841 points in 0.0312s.
# ⏱ Running HECI with 23539 points...
# ✅ Completed 23539 points in 0.0534s.
# ⏱ Running HECI with 40026 points...
# ✅ Completed 40026 points in 0.1006s.
# ⏱ Running HECI with 68054 points...
# ✅ Completed 68054 points in 0.1478s.
# ⏱ Running HECI with 115701 points...
# ✅ Completed 115701 points in 0.2109s.
# ⏱ Running HECI with 196701 points...
# ✅ Completed 196701 points in 0.4659s.
# ⏱ Running HECI with 209673 points...
# ✅ Completed 209673 points in 0.4860s.
# 📊 Benchmark results saved to results\times.csv
# ⏩ Skipping n=10 for IGCI (already computed with same parameters)
# ⏩ Skipping n=27 for IGCI (already computed with same parameters)
# ⏩ Skipping n=55 for IGCI (already computed with same parameters)
# ⏩ Skipping n=103 for IGCI (already computed with same parameters)
# ⏩ Skipping n=185 for IGCI (already computed with same parameters)
# ⏩ Skipping n=324 for IGCI (already computed with same parameters)
# ⏩ Skipping n=560 for IGCI (already computed with same parameters)
# ⏩ Skipping n=962 for IGCI (already computed with same parameters)
# ⏩ Skipping n=1645 for IGCI (already computed with same parameters)
# ⏩ Skipping n=2806 for IGCI (already computed with same parameters)
# ⏩ Skipping n=4780 for IGCI (already computed with same parameters)
# ⏩ Skipping n=8136 for IGCI (already computed with same parameters)
# ⏩ Skipping n=13841 for IGCI (already computed with same parameters)
# ⏩ Skipping n=23539 for IGCI (already computed with same parameters)
# ⏩ Skipping n=40026 for IGCI (already computed with same parameters)
# ⏩ Skipping n=68054 for IGCI (already computed with same parameters)
# ⏩ Skipping n=115701 for IGCI (already computed with same parameters)
# ⏩ Skipping n=196701 for IGCI (already computed with same parameters)
# ⏩ Skipping n=209673 for IGCI (already computed with same parameters)
# 📊 Benchmark results saved to results\times.csv
# ⏱ Running LCube with 10 points...
# ✅ Completed 10 points in 0.0000s.
# ⏱ Running LCube with 27 points...
# ✅ Completed 27 points in 0.0000s.
# ⏱ Running LCube with 55 points...
# ✅ Completed 55 points in 0.0000s.
# ⏱ Running LCube with 103 points...
# ✅ Completed 103 points in 0.0020s.
# ⏱ Running LCube with 185 points...
# ✅ Completed 185 points in 0.0006s.
# ⏱ Running LCube with 324 points...
# ✅ Completed 324 points in 0.0000s.
# ⏱ Running LCube with 560 points...
# ✅ Completed 560 points in 0.0000s.
# ⏱ Running LCube with 962 points...
# ✅ Completed 962 points in 0.0193s.
# ⏱ Running LCube with 1645 points...
# ✅ Completed 1645 points in 0.0120s.
# ⏱ Running LCube with 2806 points...
# ✅ Completed 2806 points in 0.0244s.
# ⏱ Running LCube with 4780 points...
# ✅ Completed 4780 points in 0.0084s.
# ⏱ Running LCube with 8136 points...
# ✅ Completed 8136 points in 0.0377s.
# ⏱ Running LCube with 13841 points...
# ✅ Completed 13841 points in 0.0685s.
# ⏱ Running LCube with 23539 points...
# ✅ Completed 23539 points in 0.0603s.
# ⏱ Running LCube with 40026 points...
# ✅ Completed 40026 points in 0.0917s.
# ⏱ Running LCube with 68054 points...
# ✅ Completed 68054 points in 0.1001s.
# ⏱ Running LCube with 115701 points...
# ✅ Completed 115701 points in 0.3163s.
# ⏱ Running LCube with 196701 points...
# ✅ Completed 196701 points in 0.7332s.
# ⏱ Running LCube with 209673 points...
# ✅ Completed 209673 points in 0.8663s.
# 📊 Benchmark results saved to results\times.csv
# ⏱ Running LOCI with 10 points...
# ✅ Completed 10 points in 11.2104s.
# ⏱ Running LOCI with 27 points...
# ✅ Completed 27 points in 13.2337s.
# ⏱ Running LOCI with 55 points...
# ✅ Completed 55 points in 13.9464s.
# ⏱ Running LOCI with 103 points...
# ✅ Completed 103 points in 15.1382s.
# ⏱ Running LOCI with 185 points...
# ✅ Completed 185 points in 16.8310s.
# ⏱ Running LOCI with 324 points...
# ✅ Completed 324 points in 19.3448s.
# ⏱ Running LOCI with 560 points...
# ✅ Completed 560 points in 22.6560s.
# ⏱ Running LOCI with 962 points...
# ✅ Completed 962 points in 30.0743s.
# ⏱ Running LOCI with 1645 points...
# ✅ Completed 1645 points in 44.8796s.
# ⏱ Running LOCI with 2806 points...
# ✅ Completed 2806 points in 70.8405s.
# ⏱ Running LOCI with 4780 points...
# ✅ Completed 4780 points in 116.4560s.
# ⏱ Running LOCI with 8136 points...
# ✅ Completed 8136 points in 230.7411s.
# ⏱ Running LOCI with 13841 points...
# ✅ Completed 13841 points in 501.8401s.
# ⏱ Running LOCI with 23539 points...
# ✅ Completed 23539 points in 1283.2021s.
# ⏱ Running LOCI with 40026 points...
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x000001C4660AE0D0>>
# Traceback (most recent call last):
#   File "c:\Users\tiago\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:

# %%
plot_execution_times()
# Out:
# 📊 Crossing Points (time ≈ target_time):
# ANM: ≈ 6419.15 points
# CGNN: ≈ -0.38 points
# FOM: ≈ -302457.03 points
# HECI: ≈ 6374606.19 points
# IGCI: ≈ -15486037.77 points
# LCube: ≈ 1100064.89 points
# LOCI: ≈ -0.17 points
# LiNGAM: ≈ 9161398.53 points
# ROCHE: ≈ -30.39 points
# bqcd: ≈ 47061.39 points
# cam: ≈ 52568440.46 points
# cdci: ≈ 6308036.17 points
# cds: ≈ 948732.18 points
# fom: ≈ 797.29 points
# heci: ≈ 853858.61 points
# nncl: ≈ -2338664.83 points
# sloppy: ≈ 156568.93 points
# {'ANM': 6419.148606659108,
#  'CGNN': -0.37852024501844816,
#  'FOM': -302457.02588977705,
#  'HECI': 6374606.189814925,
#  'IGCI': -15486037.771940054,
#  'LCube': 1100064.891114388,
#  'LOCI': -0.16975437644696,
#  'LiNGAM': 9161398.529011615,
#  'ROCHE': -30.392213807446588,
#  'bqcd': 47061.39451067302,
#  'cam': 52568440.459034026,
#  'cdci': 6308036.167487268,
#  'cds': 948732.1833556304,
#  'fom': 797.2903921109121,
#  'heci': 853858.6106990881,
#  'nncl': -2338664.8253615075,
#  'sloppy': 156568.9330245056}
