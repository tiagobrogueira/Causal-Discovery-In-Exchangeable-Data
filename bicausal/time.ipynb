# %%
from bicausal.helpers.timers import benchmark_function, plot_execution_times
from bicausal.methods.IGCI import igci
from bicausal.methods.LOCI import loci
from bicausal.methods.LCUBE import lcube
from bicausal.methods.ANM import anm
from bicausal.methods.CGNN import cgnn
from bicausal.methods.HECI import heci
from bicausal.methods.NNCL import nncl
from bicausal.methods.ROCHE import roche
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
test_file="benchmarks/Lisbon/data/economy/taxi_fare_prediction/distance_traveled_fare.txt"
#RUN FUNCTIONS ONE AT A TIME; TO BREAK WHEN TOO LONG~
#hello
benchmark_function(roche,test_file,overwrite=True)
# Out:
# ⏱ Running ROCHE with 10 points...
# ✅ Completed 10 points in 10.2879s.
# ⏱ Running ROCHE with 27 points...
# ✅ Completed 27 points in 10.4091s.
# ⏱ Running ROCHE with 55 points...
# ✅ Completed 55 points in 11.7642s.
# ⏱ Running ROCHE with 103 points...
# ✅ Completed 103 points in 12.3388s.
# ⏱ Running ROCHE with 185 points...
# ✅ Completed 185 points in 16.2280s.
# ⏱ Running ROCHE with 324 points...
# ✅ Completed 324 points in 21.2565s.
# ⏱ Running ROCHE with 560 points...
# ✅ Completed 560 points in 27.5785s.
# ⏱ Running ROCHE with 962 points...
# ✅ Completed 962 points in 37.1027s.
# ⏱ Running ROCHE with 1645 points...
# ✅ Completed 1645 points in 64.3416s.
# ⏱ Running ROCHE with 2806 points...
# ✅ Completed 2806 points in 86.9283s.
# ⏱ Running ROCHE with 4780 points...
# ✅ Completed 4780 points in 137.4307s.
# ⏱ Running ROCHE with 8136 points...
# ✅ Completed 8136 points in 282.7075s.
# ⏱ Running ROCHE with 13841 points...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 test_file="benchmarks/Lisbon/data/economy/taxi_fare_prediction/distance_traveled_fare.txt"
#       2 #RUN FUNCTIONS ONE AT A TIME; TO BREAK WHEN TOO LONG~
#       3 #hello
# ----> 4 benchmark_function(roche,test_file,overwrite=True)
#
# File ~\Desktop\Causal-Discovery-In-Exchangeable-Data\bicausal\helpers\timers.py:58, in benchmark_function(func, test_file, write_dir, overwrite, seed, *args, **kwargs)
#      56 start = time.time()
#      57 try:
# ---> 58     func(subset, *args, **kwargs)
#      59 except Exception as e:
#      60     print(f"⚠️ Error at n={n_points}: {e}")
#
# File ~\Desktop\Causal-Discovery-In-Exchangeable-Data\bicausal\methods\ROCHE.py:15, in roche(d)
#      12 y = y.flatten()
#      14 try:
# ---> 15     return original_roche.roche(x, y)
#      16 except Exception as e:
#      17     print("Error in roche.roche:")
#
# File ~\Desktop\Causal-Discovery-In-Exchangeable-Data\bicausal\methods\source_implementations\ROCHE_main\causa\roche.py:193, in roche(x, y, independence_test, return_function, n_steps, device, verbose)
#     170 """Robust estimation of causal heteroscedastic noise models (ROCHE) for bivariate pairs.
#     171 By default, the method returns a score for the x -> y causal direction where above 0
#     172 indicates evidence for it and negative values indicate y -> x.
#    (...)    189     number of epochs to train neural network or steps to optimize convex model
#     190 """
#     191 assert x.ndim == y.ndim == 1, 'x and y have to be 1-dimensional arrays'
# --> 193 log_lik_forward, f_forward = het_fit_nn(x, y, n_steps, device=device, verbose=verbose)
#     194 log_lik_reverse, f_reverse = het_fit_nn(y, x, n_steps, device=device, verbose=verbose)
#     196 if independence_test:
#
# File ~\Desktop\Causal-Discovery-In-Exchangeable-Data\bicausal\methods\source_implementations\ROCHE_main\causa\roche.py:148, in het_fit_nn(x, y, n_steps, seed, device, verbose)
#     143 loader = TensorDataLoader(
#     144     x.reshape(-1, 1).to(device), y.flatten().to(device),
#     145     batch_size=len(x),
#     146 )
#     147 set_seed(seed)
# --> 148 model, losses = map_optimization(
#     149     build_het_network().to(device).double(),
#     150     loader,
#     151     verbose=verbose,
#     152     **map_kwargs
#     153 )
#     155 @torch.no_grad()
#     156 def f(x_):
#     157     x_ = torch.from_numpy(x_[:, np.newaxis]).double().to(device)
#
# File ~\Desktop\Causal-Discovery-In-Exchangeable-Data\bicausal\methods\source_implementations\ROCHE_main\causa\roche.py:115, in map_optimization(model, train_loader, n_epochs, lr, lr_min, verbose)
#     113 loss = loss / N
#     114 constraint =  constraint / N
# --> 115 (loss + constraint).backward()
#     116 optimizer.step()
#     117 scheduler.step()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)    624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\autograd\graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
plot_execution_times()
# Out:
# 📊 Crossing Points (time ≈ target_time):
# ANM: ≈ 9897.15 points
# IGCI: ≈ -47212967.32 points
# LiNGAM: ≈ 27304826.40 points
# ROCHE: ≈ 662.21 points
# bqcd: ≈ 135140.75 points
# cam: ≈ 199737798.01 points
# heci: ≈ 2261308.95 points
# nncl: ≈ -7804192.83 points
# sloppy: ≈ 758406.37 points
# {'ANM': 9897.14733768682,
#  'IGCI': -47212967.323517404,
#  'LiNGAM': 27304826.39615849,
#  'ROCHE': 662.2084480112708,
#  'bqcd': 135140.74672807372,
#  'cam': 199737798.01384524,
#  'heci': 2261308.9499088144,
#  'nncl': -7804192.833116521,
#  'sloppy': 758406.3661582377}
