# %%
from bicausal.helpers.timers import benchmark_function, plot_execution_times

from bicausal.methods.ANM import anm
from bicausal.methods.CDCI import cdci
from bicausal.methods.CDS import cds
from bicausal.methods.CGNN import cgnn
from bicausal.methods.FOM import fom
from bicausal.methods.HECI import heci
from bicausal.methods.IGCI import igci
from bicausal.methods.LCUBE import lcube
from bicausal.methods.LOCI import loci
from bicausal.methods.NNCL import nncl
from bicausal.methods.RECI import reci
from bicausal.methods.ROCHE import roche
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
test_file="benchmarks/Lisbon/data/economy/taxi_fare_prediction/distance_traveled_fare.txt"
#RUN FUNCTIONS ONE AT A TIME; TO BREAK WHEN TOO LONG~
#hello
#benchmark_function(anm,test_file)
#benchmark_function(cdci,test_file)
#benchmark_function(cds,test_file)
#benchmark_function(cgnn,test_file,overwrite=True)
#benchmark_function(fom,test_file)
#benchmark_function(heci,test_file)
#benchmark_function(igci,test_file)
#benchmark_function(lcube,test_file)
#benchmark_function(loci,test_file)
#benchmark_function(nncl,test_file)
#benchmark_function(reci,test_file)
#benchmark_function(roche,test_file)

# %%
benchmark_function(fom,test_file,overwrite=True)
# Out:
# ⏱ Running FOM with 10 points...
# N: 10
#   File "c:\Users\tiago\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "c:\Users\tiago\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tiago\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\tiago\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ✅ Completed 10 points in 0.2479s.
# ⏱ Running FOM with 27 points...
# N: 27
# ✅ Completed 27 points in 0.1594s.
# ...

# %%
benchmark_function(cgnn,test_file,overwrite=True,train_epochs=10,nruns=3,test_epochs=2)
# Out:
# ⏱ Running CGNN with 10 points...
# ✅ Completed 10 points in 0.6448s.
# ⏱ Running CGNN with 27 points...
# ✅ Completed 27 points in 1.3764s.
# ⏱ Running CGNN with 55 points...
# ✅ Completed 55 points in 2.8589s.
# ⏱ Running CGNN with 103 points...
# ✅ Completed 103 points in 5.8703s.
# ⏱ Running CGNN with 185 points...
# ✅ Completed 185 points in 11.4220s.
# ⏱ Running CGNN with 324 points...
# ✅ Completed 324 points in 19.2633s.
# ⏱ Running CGNN with 560 points...
# ✅ Completed 560 points in 35.4692s.
# ⏱ Running CGNN with 962 points...
# ✅ Completed 962 points in 59.7203s.
# ⏱ Running CGNN with 1645 points...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 benchmark_function(cgnn,test_file,overwrite=True,train_epochs=10,nruns=3,test_epochs=2)
#
# ...

# %%
plot_execution_times(target_time=20)
# Out:
# 📊 Crossing Points (time ≈ target_time):
# ANM: ≈ 8659.55 points
# CAM: ≈ 126153119.24 points
# CDCI: ≈ 12494969.62 points
# CDS: ≈ 1855197.76 points
# CGNN: ≈ 324.00 points
# FOM: ≈ 1636.56 points
# HECI: ≈ 12854432.73 points
# IGCI: ≈ -31349502.55 points
# LCube: ≈ 2074905.95 points
# LOCI: ≈ 370.70 points
# NNCL: ≈ -5071428.83 points
# ROCHE: ≈ 289.27 points
# Sloppy: ≈ 434308.12 points
# bQCD: ≈ 92674.50 points
# {'ANM': 8659.552924743039,
#  'CAM': 126153119.23643963,
#  'CDCI': 12494969.621507552,
#  'CDS': 1855197.7620117054,
#  'CGNN': 324.0,
#  'FOM': 1636.5602768810572,
#  'HECI': 12854432.72531739,
#  'IGCI': -31349502.54772873,
#  'LCube': 2074905.9485798033,
#  'LOCI': 370.69996908211624,
#  'NNCL': -5071428.829239015,
#  'ROCHE': 289.26703281958453,
#  'Sloppy': 434308.1208518638,
#  'bQCD': 92674.50154011113}
