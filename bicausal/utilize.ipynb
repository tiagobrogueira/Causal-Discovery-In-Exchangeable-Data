# %%
from bicausal.helpers.utils import correct_names, nanning, delete_repeated_lines

# %%
delete_repeated_lines()
# Out:
# --- Processing ANLSMN_scores.csv ---
# Attempting robust timestamp parsing...
# No new repeated lines found in ANLSMN_scores.csv.
# --- Processing CE_scores.csv ---
# Attempting robust timestamp parsing...
# No new repeated lines found in CE_scores.csv.
# --- Processing lisbon_scores.csv ---
# Attempting robust timestamp parsing...
# No new repeated lines found in lisbon_scores.csv.
# --- Processing results.csv ---
# Attempting robust timestamp parsing...
# No new repeated lines found in results.csv.
# --- Processing SIM_scores.csv ---
# Attempting robust timestamp parsing...
# No new repeated lines found in SIM_scores.csv.
# --- Processing times.csv ---
# Attempting robust timestamp parsing...
# Successfully deleted 1 repeated (older) lines from times.csv.
# --- Processing tuebingen_scores.csv ---
# Attempting robust timestamp parsing...
# No new repeated lines found in tuebingen_scores.csv.
# --- Processing unimplemented_results.csv ---
# ...

# %%
correct_names()

# %%
nanning()
# Out:
# Processing results\ANLSMN_scores.csv
# Processing results\CE_scores.csv
# Processing results\lisbon_scores.csv
# Processing results\results.csv
# Processing results\SIM_scores.csv
# Processing results\times.csv
# Processing results\tuebingen_scores.csv
# Processing results\unimplemented_results.csv
